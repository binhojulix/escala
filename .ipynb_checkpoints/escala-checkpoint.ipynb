# %% [markdown]
# # Escala - Analise de SSL's

# %%
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
print(sns.__version__)
# Out:
# 0.9.0

# %%
path_bruto = r'C:\\Users\\cptm\Documents\\GitHub\\escala\\bruto'
path_normalizado = r'C:\\Users\\cptm\Documents\\GitHub\\escala\\normalizado'
all_files = glob.glob(path_bruto + "\\*xlsx")

for filename in all_files:
    name = filename.split("\\")
    name = name[len(name)-1]
    os.chmod(filename, 0o777)
    df = pd.read_excel(filename, skiprows = 2) #Read Excel file as a DataFrame
    df.to_excel(path_normalizado + "\\" + name , index=False)

# %%
path = r'C:\\Users\\cptm\Documents\\GitHub\\escala\\normalizado' # use your path
all_files = glob.glob(path + "\\*xlsx")

li = []

for filename in all_files:
    df = pd.read_excel(filename, index_col=None, header=0)
    li.append(df)
    
df = pd.concat(li, axis=0, ignore_index=True)
df = df[['DataSolicitacao', 'Quantidade']]
df["DataSolicitacao"] = pd.to_datetime(df['DataSolicitacao'], format='%d/%m/%Y %H:%M:%S')
df.to_excel('ssl.xlsx' , index=False)
df.head()
# Out:
#       DataSolicitacao  Quantidade
# 0 2021-03-15 08:52:31           1
# 1 2021-03-15 14:56:21           1
# 2 2021-03-15 15:34:22           1
# 3 2021-03-16 02:41:58           1
# 4 2021-03-16 09:54:29           1

# %%
print(df.dtypes)
print(df.shape)
df = pd.DataFrame(df.set_index('DataSolicitacao').resample('M')["Quantidade"].sum())
df.head()
# Out:
# DataSolicitacao    datetime64[ns]
# Quantidade                  int64
# dtype: object
# (6452, 2)
#                  Quantidade
# DataSolicitacao
# 2019-01-31              334
# 2019-02-28              274
# 2019-03-31              444
# 2019-04-30              310
# 2019-05-31              412
# 2019-06-30              175
# 2019-07-31              257
# 2019-08-31              205
# 2019-09-30              265
# 2019-10-31              231

# %% [markdown]
# # SSL - Análise Abertura de ssl's

# %%
df1 = pd.read_excel("ssl.xlsx", index_col=None, header=0)
df1 = df1[['DataSolicitacao', 'Quantidade']]
df1 = df1.rename(columns={'DataSolicitacao': 'data', 'Quantidade': 'quantidade'})
df1["data"] = pd.to_datetime(df1['data'])
#df1 = df1.iloc[: , 1:]
print('Tipo de Dados:\n', df1.dtypes)
print('Quantidade de linhas e colunas:', df1.shape)
df1.head()
# Out:
# Tipo de Dados:
#  data          datetime64[ns]
# quantidade             int64
# dtype: object
# Quantidade de linhas e colunas: (6452, 2)
#                  data  quantidade
# 0 2021-03-15 08:52:31           1
# 1 2021-03-15 14:56:21           1
# 2 2021-03-15 15:34:22           1
# 3 2021-03-16 02:41:58           1
# 4 2021-03-16 09:54:29           1

# %%
df1 = pd.DataFrame(df1.set_index('data').resample('M')["quantidade"].sum())
df1['data'] = df1.index
df1.reset_index(drop=True, inplace=True)
df1.head()
# Out:
#    quantidade       data
# 0         334 2019-01-31
# 1         274 2019-02-28
# 2         444 2019-03-31
# 3         310 2019-04-30
# 4         412 2019-05-31

# %%
sns.set_palette('Accent')
sns.set_style('darkgrid')
ax = sns.lineplot(x='data', y='quantidade', data=df1)
ax.figure.set_size_inches(12,6)
ax.set_title('SSL\'s de 2019 à 2021', loc='left', fontsize=18)
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Quanitdade (un)', fontsize=14)
ax = ax

# %%
df1['aumento'] =df1['quantidade'].diff()
df1.head()
# Out:
#    quantidade       data  aumento
# 0         334 2019-01-31      NaN
# 1         274 2019-02-28    -60.0
# 2         444 2019-03-31    170.0
# 3         310 2019-04-30   -134.0
# 4         412 2019-05-31    102.0

# %%
sns.set_palette('Accent')
sns.set_style('darkgrid')
ax = sns.lineplot(x='data', y='aumento', data=df1)
ax.figure.set_size_inches(12,6)
ax.set_title('Aumento de SSl\'s de 2019 à 2021', loc='left', fontsize=18)
ax.set_xlabel('Data', fontsize=14)
ax.set_ylabel('Aumento', fontsize=14)
ax = ax

# %%
def plotar(titulo, labelx, labely, x, y, dataset):
  sns.set_palette('Accent')
  sns.set_style('darkgrid')
  ax = sns.lineplot(x=x, y=y, data=dataset)
  ax.figure.set_size_inches(12,6)
  ax.set_title(titulo, loc='left', fontsize=18)
  ax.set_xlabel(labelx, fontsize=14)
  ax.set_ylabel(labely, fontsize=14)
  ax = ax

# %%
plotar('Aumento de SSl\'s de 2019 à 2021', 'Data', 'Aumento',
      'data', 'aumento', df1)

# %%
df1['aceleracao'] = df1['aumento'].diff()
df1.head()
# Out:
#    quantidade       data  aumento  aceleracao
# 0         334 2019-01-31      NaN         NaN
# 1         274 2019-02-28    -60.0         NaN
# 2         444 2019-03-31    170.0       230.0
# 3         310 2019-04-30   -134.0      -304.0
# 4         412 2019-05-31    102.0       236.0

# %%
plotar('Aceleração de SSl\'s de 2019 à 2021', 'Data', 'Aceleração',
      'data', 'aceleracao', df1)

# %%
plt.figure(figsize=(16,12))
ax = plt.subplot(3,1,1)
ax.set_title('Análise de SSl\'s de 2019 à 2021', fontsize=18,loc='left')
sns.lineplot(x='data', y='quantidade', data=df1)
plt.subplot(3,1,2)
sns.lineplot(x='data', y='aumento', data=df1)
plt.subplot(3,1,3)
sns.lineplot(x='data', y='aceleracao', data=df1)
ax = ax

# %%
def plot_comparacao(x, y1, y2, y3, dataset, titulo):
  plt.figure(figsize=(16,12))
  ax = plt.subplot(3,1,1)
  ax.set_title(titulo, fontsize=18,loc='left')
  sns.lineplot(x=x, y=y1, data=dataset)
  plt.subplot(3,1,2)
  sns.lineplot(x=x, y=y2, data=dataset)
  plt.subplot(3,1,3)
  sns.lineplot(x=x, y=y3, data=dataset)
  ax = ax

# %%
plot_comparacao('data', 'quantidade', 'aumento', 'aceleracao',
              df1, 'Análise de SSl\'s de 2019 à 2021')

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação de quantidade', fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(df1['quantidade'])
ax = ax

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação do aumento', fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(df1['aumento'][1:])
ax = ax

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação da aceleração', fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(df1['aceleracao'][2:])
ax = ax

# %% [markdown]
# # Análise diária

# %%
df1 = pd.read_excel("ssl.xlsx", index_col=None, header=0)
df1 = df1[['DataSolicitacao', 'Quantidade']]
df1 = df1.rename(columns={'DataSolicitacao': 'data', 'Quantidade': 'quantidade'})
df1["data"] = pd.to_datetime(df1['data'])
#df1 = df1.iloc[: , 1:]
print('Tipo de Dados:\n', df1.dtypes)
print('Quantidade de linhas e colunas:', df1.shape)
df1.head()
# Out:
# Tipo de Dados:
#  data          datetime64[ns]
# quantidade             int64
# dtype: object
# Quantidade de linhas e colunas: (6452, 2)
#                  data  quantidade
# 0 2021-03-15 08:52:31           1
# 1 2021-03-15 14:56:21           1
# 2 2021-03-15 15:34:22           1
# 3 2021-03-16 02:41:58           1
# 4 2021-03-16 09:54:29           1

# %%
df1 = df1[pd.to_datetime(df1['data']).dt.month == 3]
df1 = df1[pd.to_datetime(df1['data']).dt.year == 2021]
print(df1.shape)
print(df1.dtypes)
df1.head()
# Out:
# (168, 2)
# data          datetime64[ns]
# quantidade             int64
# dtype: object
#                  data  quantidade
# 0 2021-03-15 08:52:31           1
# 1 2021-03-15 14:56:21           1
# 2 2021-03-15 15:34:22           1
# 3 2021-03-16 02:41:58           1
# 4 2021-03-16 09:54:29           1

# %%
df1 = pd.DataFrame(df1.set_index('data').resample('D')["quantidade"].sum())
df1['data'] = df1.index
df1.reset_index(drop=True, inplace=True)
print(df1.shape)
print(df1.dtypes)
df1.head()
# Out:
# (31, 2)
# quantidade             int64
# data          datetime64[ns]
# dtype: object
#    quantidade       data
# 0           7 2021-03-01
# 1           5 2021-03-02
# 2           4 2021-03-03
# 3           3 2021-03-04
# 4          12 2021-03-05

# %%
df1['aumento'] = df1['quantidade'].diff()
df1['aceleracao'] = df1['aumento'].diff()
df1.head()
# Out:
#    quantidade       data  aumento  aceleracao
# 0           7 2021-03-01      NaN         NaN
# 1           5 2021-03-02     -2.0         NaN
# 2           4 2021-03-03     -1.0         1.0
# 3           3 2021-03-04     -1.0         0.0
# 4          12 2021-03-05      9.0        10.0

# %%
plot_comparacao('data', 'quantidade', 'aumento', 'aceleracao',
               df1, 'Análise de abertura de SSL\'s de Março laboratório de Presidente Altino')

# %% [markdown]
# # Analise da sazonalidade

# %%
df1['dia_da_semana'] = df1['data'].dt.strftime("%A")
df1['dia_da_semana'].unique()

dias_traduzidos = {'Monday':'Segunda', 'Tuesday':'Terca', 'Wednesday':'Quarta',
                   'Thursday':'Quinta', 'Friday':'Sexta', 'Saturday':'Sabado', 'Sunday':'Domingo'}

df1['dia_da_semana'] = df1['dia_da_semana'].map(dias_traduzidos)

print(df1.shape)
print(df1.dtypes)
df1.head()
# Out:
# (31, 5)
# quantidade                int64
# data             datetime64[ns]
# aumento                 float64
# aceleracao              float64
# dia_da_semana            object
# dtype: object
#    quantidade       data  aumento  aceleracao dia_da_semana
# 0           7 2021-03-01      NaN         NaN       Segunda
# 1           5 2021-03-02     -2.0         NaN         Terca
# 2           4 2021-03-03     -1.0         1.0        Quarta
# 3           3 2021-03-04     -1.0         0.0        Quinta
# 4          12 2021-03-05      9.0        10.0         Sexta

# %%
df1['dia_da_semana'].unique()
print(df1.shape)
print(df1.dtypes)
df1.head()
# Out:
# (31, 5)
# quantidade                int64
# data             datetime64[ns]
# aumento                 float64
# aceleracao              float64
# dia_da_semana            object
# dtype: object
#    quantidade       data  aumento  aceleracao dia_da_semana
# 0           7 2021-03-01      NaN         NaN       Segunda
# 1           5 2021-03-02     -2.0         NaN         Terca
# 2           4 2021-03-03     -1.0         1.0        Quarta
# 3           3 2021-03-04     -1.0         0.0        Quinta
# 4          12 2021-03-05      9.0        10.0         Sexta

# %%
df1_agrupado = df1.groupby('dia_da_semana')['quantidade', 'aumento', 'aceleracao'].mean().round()
print(df1_agrupado.shape)
print(df1_agrupado.dtypes)
df1_agrupado.head()
# Out:
# <ipython-input-83-9a5fc95b8eb1>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1_agrupado = df1.groupby('dia_da_semana')['quantidade', 'aumento', 'aceleracao'].mean().round()
# (7, 3)
# quantidade    float64
# aumento       float64
# aceleracao    float64
# dtype: object
#                quantidade  aumento  aceleracao
# dia_da_semana
# Domingo               0.0     -2.0         2.0
# Quarta                6.0     -1.0         3.0
# Quinta                4.0     -2.0        -2.0
# Sabado                2.0     -4.0        -6.0
# Segunda              10.0     11.0        13.0

# %% [markdown]
# correlação de abertura de ssl semanal

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação das vendas aberturas de SSL\'s dirárias', fontsize=18, x=0.3, y=0.95)
autocorrelation_plot(df1['quantidade'])
ax = ax

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação do aumento das aberturas de SSL\'s dirárias', fontsize=18, x=0.35, y=0.95)
autocorrelation_plot(df1['aumento'][1:])
ax = ax

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação da aceleração das aberturas de SSL\'s dirárias', fontsize=18, x=0.35, y=0.95)
autocorrelation_plot(df1['aceleracao'][2:])
ax = ax

# %% [markdown]
# # Análise de abertura de SSL

# %%
quantidade_de_dias_de_fds = pd.read_csv('dias_final_de_semana_2.csv')
quantidade_de_dias_de_fds.head()
# Out:
#    quantidade_de_dias
# 0                   4
# 1                   4
# 2                   5
# 3                   4
# 4                   4

# %%
df1 = pd.read_excel("ssl.xlsx", index_col=None, header=0)
df1 = df1[['DataSolicitacao', 'Quantidade']]
df1 = df1.rename(columns={'DataSolicitacao': 'data', 'Quantidade': 'quantidade'})
df1["data"] = pd.to_datetime(df1['data'])
#df1 = df1.iloc[: , 1:]
print('Tipo de Dados:\n', df1.dtypes)
print('Quantidade de linhas e colunas:', df1.shape)
df1.head()
# Out:
# Tipo de Dados:
#  data          datetime64[ns]
# quantidade             int64
# dtype: object
# Quantidade de linhas e colunas: (6452, 2)
#                  data  quantidade
# 0 2021-03-15 08:52:31           1
# 1 2021-03-15 14:56:21           1
# 2 2021-03-15 15:34:22           1
# 3 2021-03-16 02:41:58           1
# 4 2021-03-16 09:54:29           1

# %%
df1 = pd.DataFrame(df1.set_index('data').resample('M')["quantidade"].sum())
df1['data'] = df1.index
df1.reset_index(drop=True, inplace=True)
df1.head()
# Out:
#    quantidade       data
# 0         334 2019-01-31
# 1         274 2019-02-28
# 2         444 2019-03-31
# 3         310 2019-04-30
# 4         412 2019-05-31

# %%
quantidade_de_dias_de_fds['quantidade_de_dias'].values
# Out:
# array([4, 4, 5, 4, 4, 5, 4, 5, 4, 4, 5, 4, 4, 5, 4, 4, 5, 4, 4, 5, 4, 5,
#        4, 4, 5, 4, 4, 2], dtype=int64)

# %%
df1['quantidade_normalizadas'] = df1['quantidade'] / quantidade_de_dias_de_fds['quantidade_de_dias'].values
df1.head()
# Out:
#    quantidade       data  quantidade_normalizadas
# 0         334 2019-01-31                     83.5
# 1         274 2019-02-28                     68.5
# 2         444 2019-03-31                     88.8
# 3         310 2019-04-30                     77.5
# 4         412 2019-05-31                    103.0

# %%
plotar('Abertura normalizadas de SSL\'s de 2019 a 2021',
      'Data', 'Quantidades normalizadas', 'data', 'quantidade_normalizadas',
      df1)

# %%
plt.figure(figsize=(16,12))
ax = plt.subplot(2,1,1)
ax.set_title('SSL\'s', fontsize=18)
sns.lineplot(x='data', y='quantidade', data=df1)
ax = plt.subplot(2,1,2)
ax.set_title('SSL\'s normalizadas', fontsize=18)
sns.lineplot(x='data', y='quantidade_normalizadas', data=df1)
ax = ax

# %% [markdown]
# series estacionaria

# %%
df1 = pd.read_excel("ssl.xlsx", index_col=None, header=0)
df1 = df1[['DataSolicitacao', 'Quantidade']]
df1 = df1.rename(columns={'DataSolicitacao': 'data', 'Quantidade': 'quantidade'})
df1["data"] = pd.to_datetime(df1['data'])
#df1 = df1.iloc[: , 1:]
print('Tipo de Dados:\n', df1.dtypes)
print('Quantidade de linhas e colunas:', df1.shape)
df1.head()
# Out:
# Tipo de Dados:
#  data          datetime64[ns]
# quantidade             int64
# dtype: object
# Quantidade de linhas e colunas: (6452, 2)
#                  data  quantidade
# 0 2021-03-15 08:52:31           1
# 1 2021-03-15 14:56:21           1
# 2 2021-03-15 15:34:22           1
# 3 2021-03-16 02:41:58           1
# 4 2021-03-16 09:54:29           1

# %%
df1 = pd.DataFrame(df1.set_index('data').resample('M')["quantidade"].sum())
df1['data'] = df1.index
df1.reset_index(drop=True, inplace=True)
df1.head()
# Out:
#    quantidade       data
# 0         334 2019-01-31
# 1         274 2019-02-28
# 2         444 2019-03-31
# 3         310 2019-04-30
# 4         412 2019-05-31

# %%
df1['aumento'] = df1['quantidade'].diff()
df1['aceleracao'] = df1['aumento'].diff()
df1.head()
# Out:
#    quantidade       data  aumento  aceleracao
# 0         334 2019-01-31      NaN         NaN
# 1         274 2019-02-28    -60.0         NaN
# 2         444 2019-03-31    170.0       230.0
# 3         310 2019-04-30   -134.0      -304.0
# 4         412 2019-05-31    102.0       236.0

# %%
resultado = seasonal_decompose(df1['quantidade'], freq=3,)
ax = resultado.plot()
# Out:
# <ipython-input-127-8d6d0a466186>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   resultado = seasonal_decompose(df1['quantidade'], freq=3,)

# %%
observacao = resultado.observed
tendencia = resultado.trend
sazonalidade = resultado.seasonal
ruido = resultado.resid

# %%
data = ({
    'observacao':observacao,
    'tendencia':tendencia,
    'sazonalidade':sazonalidade,
    'ruido':ruido
})

resultado = pd.DataFrame(data)
resultado.head()
# Out:
#    observacao   tendencia  sazonalidade       ruido
# 0       334.0         NaN     33.484568         NaN
# 1       274.0  350.666667     -6.612654  -70.054012
# 2       444.0  342.666667    -26.871914  128.205247
# 3       310.0  388.666667     33.484568 -112.151235
# 4       412.0  299.000000     -6.612654  119.612654

# %%
plot_comparacao(resultado.index, 'observacao', 'tendencia', 'sazonalidade', resultado,
               'Exemplo de Statsmodels')

# %% [markdown]
# Analise de SSL

# %%
df1 = pd.read_excel("ssl.xlsx", index_col=None, header=0)
df1 = df1[['DataSolicitacao', 'Quantidade']]
df1 = df1.rename(columns={'DataSolicitacao': 'data', 'Quantidade': 'quantidade'})
df1["data"] = pd.to_datetime(df1['data'])
#df1 = df1.iloc[: , 1:]
print('Tipo de Dados:\n', df1.dtypes)
print('Quantidade de linhas e colunas:', df1.shape)
df1.head()
# Out:
# Tipo de Dados:
#  data          datetime64[ns]
# quantidade             int64
# dtype: object
# Quantidade de linhas e colunas: (6452, 2)
#                  data  quantidade
# 0 2021-03-15 08:52:31           1
# 1 2021-03-15 14:56:21           1
# 2 2021-03-15 15:34:22           1
# 3 2021-03-16 02:41:58           1
# 4 2021-03-16 09:54:29           1

# %%
df1 = pd.DataFrame(df1.set_index('data').resample('M')["quantidade"].sum())
df1['data'] = df1.index
df1.reset_index(drop=True, inplace=True)
df1.head()
# Out:
#    quantidade       data
# 0         334 2019-01-31
# 1         274 2019-02-28
# 2         444 2019-03-31
# 3         310 2019-04-30
# 4         412 2019-05-31

# %%
df1['aumento'] = df1['quantidade'].diff()
df1['aceleracao'] = df1['aumento'].diff()
df1.head()
# Out:
#    quantidade       data  aumento  aceleracao
# 0         334 2019-01-31      NaN         NaN
# 1         274 2019-02-28    -60.0         NaN
# 2         444 2019-03-31    170.0       230.0
# 3         310 2019-04-30   -134.0      -304.0
# 4         412 2019-05-31    102.0       236.0

# %%
df1['media_movel'] = df1['quantidade'].rolling(7).mean()

# %%
df1.head(7)
# Out:
#    quantidade       data  aumento  aceleracao  media_movel
# 0         334 2019-01-31      NaN         NaN          NaN
# 1         274 2019-02-28    -60.0         NaN          NaN
# 2         444 2019-03-31    170.0       230.0          NaN
# 3         310 2019-04-30   -134.0      -304.0          NaN
# 4         412 2019-05-31    102.0       236.0          NaN
# 5         175 2019-06-30   -237.0      -339.0          NaN
# 6         257 2019-07-31     82.0       319.0   315.142857

# %%
plotar('Análise de vendas com média móvel de 7 dias',
      'Data', 'Media móvel', 'data', 'media_movel', df1)

# %%
df1['media_movel_21'] = df1['quantidade'].rolling(21).mean()

# %%
plotar('Análise de SSL\'s de 21 dias de 21 dias',
      'Data', 'Media móvel', 'data', 'media_movel_21', df1)

# %%
plot_comparacao('data', 'quantidade', 'media_movel', 'media_movel_21',
               df1, 'Comparando as SSL com médias móveis')
